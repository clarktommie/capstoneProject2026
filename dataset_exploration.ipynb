# %% [markdown]
# # K-12 School Shooting Dataset quick view
# Run the cells below to inspect the sheets in the Excel workbook.

# %%
import pandas as pd

# %%
victims_ds = pd.read_csv("Victim.csv")
victims_ds.head(5)
# Out:
#      Incident_ID   Injury Gender School_Affiliation    Age Race
# 0  20250827MNANM    Fatal    NaN            Student      8  NaN
# 1  20250827MNANM    Fatal    NaN            Student     10  NaN
# 2  20250827MNANM  Wounded    NaN            Student  Child  NaN
# 3  20250827MNANM  Wounded    NaN            Student  Child  NaN
# 4  20250827MNANM  Wounded    NaN            Student  Child  NaN

# %%
incidents_ds = pd.read_csv("Incident.csv")
incidents_ds.head(5)
# Out:
#      Incident_ID  Month  Day  Year        Date                         School  \
# 0  20250827MNANM      8   27  2025  2025-08-27   Annunciation Catholic School
# 1  20250826MNCRM      8   26  2025  2025-08-26  Cristo Rey Jesuit High School
# 2  20250822ILMAP      8   22  2025  2025-08-22             Manual High School
# 3  20250822KYMAM      8   22  2025  2025-08-22           Mayfield High School
# 4  20250820TNRIM      8   20  2025  2025-08-20        Riverview Middle School
#
#    Victims_Killed  Victims_Wounded  Number_Victims  Shooter_Killed  ...  \
# 0               2               17              19               1  ...
# 1               1                6               7               0  ...
# 2               0                0               0               0  ...
# 3               0                1               1               0  ...
# 4               0                0               0               0  ...
#
#   Preplanned  SRO_School Security_Screening     Screening_Outcome Shots_Fired  \
# 0        Yes          No                NaN  Outside/Off-Property          99
# 1         No         NaN                NaN  Outside/Off-Property          30
# 2         No         NaN                NaN  Outside/Off-Property          99
# 3         No         NaN                NaN  Outside/Off-Property          99
# 4         No         NaN                NaN                   NaN          99
#
#   School_Lockdown        LAT        LNG                     Campus_Type  \
# 0             Yes  44.904590 -93.286622     Multiple detached buildings
# 1              No  44.950010 -93.271548         Urban Street Standalone
# 2             Yes  40.679481 -89.633994     Multiple attached buildings
# 3              No  36.730095 -88.626894     Multiple attached buildings
# 4             NaN  35.096211 -90.070873  Single building indoor hallway
#
#   Zipcode
# 0   55419
# 1   55408
# 2   61605
# 3   42066
# 4   38109
#
# [5 rows x 50 columns]

# %%
shooters_ds = pd.read_csv("Shooter.csv")
shooters_ds.head(5)
# Out:
#      Incident_ID    Age  Gender Race School_Affiliation  \
# 0  20250827MNANM     23  Female  NaN                NaN
# 1  20250826MNCRM  Adult    Male  NaN        No Relation
# 2  20250822ILMAP     15    Male  NaN            Student
# 3  20250822KYMAM     14    Male  NaN            Student
# 4  20250820TNRIM  Adult  Female  NaN                NaN
#
#             Shooter_Outcome Shooter_Died   Injury
# 0                   Suicide          Yes  Suicide
# 1              Fled/Escaped           No      NaN
# 2          Fled/Apprehended           No      NaN
# 3          Fled/Apprehended           No      NaN
# 4  Apprehended/Killed by LE           No      NaN

# %%
weapons_ds = pd.read_csv("Weapon.csv")
weapons_ds.head(5)
# Out:
#      Incident_ID Weapon_Type Weapon_Caliber Weapon_Details
# 0  20250827MNANM       Rifle   .223 caliber            NaN
# 1  20250827MNANM     Shotgun       12 gauge            NaN
# 2  20250827MNANM     Handgun            NaN            NaN
# 3  20250826MNCRM       Rifle   .223 caliber    AR-15 rifle
# 4  20250822ILMAP     Handgun            NaN            NaN

# %%
# view counts in state column
incidents_ds["State"].value_counts()
# Out:
# State
# CA    288
# TX    249
# IL    162
# FL    160
# OH    149
# PA    134
# NY    134
# MI    125
# TN    121
# GA    118
# NC    116
# MD    103
# LA     88
# AL     78
# WA     76
# VA     73
# MO     66
# IN     63
# SC     61
# DC     59
# CO     48
# WI     48
# MS     40
# KY     39
# OR     39
# MN     37
# AR     37
# NJ     34
# AZ     32
# OK     32
# MA     31
# NM     30
# CT     30
# KS     29
# UT     28
# NV     26
# DE     24
# IA     23
# NE     16
# ID     12
# MT     11
# WV     10
# NH      8
# HI      8
# RI      8
# AK      7
# ME      7
# SD      6
# VT      6
# ND      4
# WY      2
# VI      1
# Name: count, dtype: int64

# %%
# row count for dataset
print(incidents_ds.shape)
print(victims_ds.shape)
print(shooters_ds.shape)
print(weapons_ds.shape)
# Out:
# (3136, 50)
# (3988, 6)
# (3487, 8)
# (3168, 4)

# %%
# school column counts with repeat shootings with more than one victim
incidents_ds["School"].value_counts()
# Out:
# School
# Central High School                            24
# Roosevelt High School                          13
# Booker T. Washington High School               13
# Dunbar High School                             10
# Lincoln High School                             9
#                                                ..
# Wisconsin Conservatory of Lifelong Learning     1
# Marietta City Schools Bus Yard                  1
# Hazelwood Central High School                   1
# Houck Middle School                             1
# Arrowview Middle School                         1
# Name: count, Length: 2639, dtype: int64

# %%
victims_ds["School_Affiliation"].value_counts()
# Out:
# School_Affiliation
# Student                                                2300
# No Relation                                             473
# Nonstudent Using Athletic Facilities/Attending Game     192
# Teacher                                                 186
# Other Staff                                              91
# Parent                                                   65
# Police Officer/SRO                                       46
# Relative                                                 45
# Principal/Vice-Principal                                 44
# Former Student                                           31
# Unknown                                                  26
# Nonstudent                                               24
# Gang Member                                              19
# Bus Driver                                               18
# Security Guard                                           15
# Intimate Relationship                                     6
# Former Teacher                                            3
# Rival School Student                                      3
# Visiting Student                                          1
# Name: count, dtype: int64
